# %%
import pandas as pd
import matplotlib.pyplot as plt

import numpy as np
import seaborn as sns
import os
import missingno as msno
import warnings

warnings.simplefilter(action = "ignore", category = RuntimeWarning)

# %%
file_6 = "EDA Important Values.xlsx"

# %%
df = pd.read_excel(file_6)

# %%
df.describe()
# Out:
#          STG_NUMBER  STG_TOP_DEPTH  STG_BOTTOM_DEPTH  \
# count  17442.000000   17442.000000      17442.000000
# mean      22.962963   15694.314815      16050.991629
# std       16.795519    2180.359989       2126.582527
# min        1.000000   10863.000000      11008.000000
# 25%       10.000000   13933.000000      14377.000000
# 50%       20.000000   15528.000000      15965.500000
# 75%       31.000000   17185.000000      17540.000000
# max      110.000000   23306.000000      23311.000000
#
#        STG_SLURRY_VOLUME_PUMPED  PROPPANT_DESIGNED  Rig Time (days)  \
# count              17442.000000       1.744100e+04     17442.000000
# mean                8628.604174       4.254413e+05        15.763586
# std                 2678.837183       1.180147e+05         6.898913
# min                  666.000000       0.000000e+00         0.500000
# 25%                 7421.250000       4.200000e+05        11.000000
# 50%                 8328.500000       4.200000e+05        14.000000
# ...

# %%
g = sns.pairplot(df)
